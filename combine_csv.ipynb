# %%
import pandas as pd 


csv_write = "/home/cshah/workspaces/deepPhase based work/Data/Vicon_SS_Data_trial/train/PAE_Vicon_train_lim.csv"
csv_write_validate = "/home/cshah/workspaces/deepPhase based work/Data/Vicon_SS_Data_trial/validate/PAE_Vicon_val_lim.csv"

# CSV's to read from
csv_files =  [
"/home/cshah/workspaces/deepPhase based work/Data/Vicon_SS_Data_trial/raw data/PAE_sub01_random_motions.csv",
"/home/cshah/workspaces/deepPhase based work/Data/Vicon_SS_Data_trial/raw data/PAE_sub01_squats.csv",
"/home/cshah/workspaces/deepPhase based work/Data/Vicon_SS_Data_trial/raw data/PAE_sub01_walk_around.csv"
]

# Read and concatenate all CSVs
# rm_df = pd.read_csv(csv_files[0])
sq_df = pd.read_csv(csv_files[1])
wa_df = pd.read_csv(csv_files[2])

# print(len(rm_df))
print(len(sq_df))
print(len(wa_df))


# rm_df_train = rm_df.iloc[4500:]
# rm_df_val = rm_df.iloc[0:4500]

sq_df_train = sq_df.iloc[5000:]
sq_df_val = sq_df.iloc[0:5000]

wa_df_train = wa_df.iloc[0:38000]
wa_df_val = wa_df.iloc[38000:]

df_list = [sq_df_train, wa_df_train]
df_train = pd.concat(df_list, ignore_index=True)

print(df_train.shape)

df_list_validate = [sq_df_val, wa_df_val]
df_val = pd.concat(df_list_validate, ignore_index=True)

print(df_val.shape)
# Out:
# 26283
# 45000
# (59283, 38)
# (12000, 38)

# %%
# Optional: sort or reset index
df_train.reset_index(drop=True, inplace=True)
df_train.to_csv(csv_write, index=False)

df_val.reset_index(drop=True, inplace=True)
df_val.to_csv(csv_write_validate, index=False)

# # Write all the validation files
# random_df_validate.reset_index(drop=True, inplace=True)
# random_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_random_validate.csv", index=False)

# squats_df_validate.reset_index(drop=True, inplace=True)
# squats_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_squats_validate.csv", index=False)

# treadmill_walking_df_validate.reset_index(drop=True, inplace=True)
# treadmill_walking_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_TW_validate.csv", index=False)

# walking_df_validate.reset_index(drop=True, inplace=True)
# walking_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_WA_validate.csv", index=False)

# %%
import pandas as pd 

csv_files = [
    "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/07_02_RM_quat.csv",
    "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/07_02_SQ_quat.csv",
    "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/07_02_TW_quat.csv",
    "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/07_09_RM_quat.csv",
    "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/07_09_SQ_quat.csv",
    "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/07_09_TW_quat.csv",
    "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/07_09_WA_quat.csv"
]

# rm_df = pd.read_csv(csv_files[0])
# sq_1_df = pd.read_csv(csv_files[1])
# tw_1_df = pd.read_csv(csv_files[2])
# rm_2_df = pd.read_csv(csv_files[0])
sq_df = pd.read_csv(csv_files[4])
tw_df = pd.read_csv(csv_files[5])
wa_df = pd.read_csv(csv_files[6])

# # rm_df = pd.concat([rm_1_df, rm_2_df], ignore_index=True)
# sq_df = pd.concat([sq_1_df, sq_2_df], ignore_index=True)
# tw_df = pd.concat([tw_1_df, tw_2_df], ignore_index=True)

# print(len(rm_df))
print(len(sq_df))
print(len(tw_df))
print(len(wa_df))

# rm_df_train = rm_df.iloc[0:13000]
# rm_df_val = rm_df.iloc[13000:]

# sq_df_train = sq_df.iloc[0:18000]
# sq_df_val = sq_df.iloc[18000:]

# tw_df_train = tw_df.iloc[0:38000]
# tw_df_val = tw_df.iloc[38000:]

# wa_df_train = wa_df.iloc[0:38000]
# wa_df_val = wa_df.iloc[38000:]

# df_list = [rm_df_train, sq_df_train, tw_df_train, wa_df_train]
# df_train = pd.concat(df_list, ignore_index=True)

# df_list_validate = [rm_df_val, sq_df_val, tw_df_val, wa_df_val]
# df_val = pd.concat(df_list_validate, ignore_index=True)
# Out:
# 22500
# 44000
# 44000

# %%
# Optional: sort or reset index

train_file = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/Quat_Sub2_train.csv"
df_train.reset_index(drop=True, inplace=True)
df_train.to_csv(train_file, index=False)

val_file = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/Quat_Sub2_val.csv"
df_val.reset_index(drop=True, inplace=True)
df_val.to_csv(val_file, index=False)

# %%
data_1 = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/Quat_Sub2_train.csv"
data_2 = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/PAE_train_Sub2_reset.csv"

df_1 = pd.read_csv(data_1)
df_2 = pd.read_csv(data_2)



sec_1_1_train = df_1.iloc[0:7000,:]
sec_1_2_train = df_2.iloc[0:7000,:]

sec_1_1_val = df_1.iloc[7000:10000,:]
sec_1_2_val = df_2.iloc[7000:10000,:]

sec_2_1_train = df_1.iloc[10000:26000,:]
sec_2_2_train = df_2.iloc[10000:26000,:]

sec_2_1_val = df_1.iloc[26000:30000,:]
sec_2_2_val = df_2.iloc[26000:30000,:]

sec_3_1_train = df_1.iloc[30000:48000,:]
sec_3_2_train = df_2.iloc[30000:48000,:]

sec_3_1_val = df_1.iloc[48000:54000,:]
sec_3_2_val = df_2.iloc[48000:54000,:]

sec_4_1_train = df_1.iloc[54000:80000,:]
sec_4_2_train = df_2.iloc[54000:80000,:]

sec_4_1_val = df_1.iloc[80000:86000,:]
sec_4_2_val = df_2.iloc[80000:86000,:]

sec_5_1_train = df_1.iloc[86000:,:]
sec_5_2_train = df_2.iloc[86000:,:]


pae_train_list = [sec_1_2_train, sec_2_2_train, sec_3_2_train, sec_4_2_train, sec_5_2_train]
pae_train = pd.concat(pae_train_list, ignore_index=True)
print(pae_train.shape)

pae_val_list = [sec_1_2_val, sec_2_2_val, sec_3_2_val, sec_4_2_val]
pae_val = pd.concat(pae_val_list, ignore_index=True)
print(pae_val.shape)

quat_train_list = [sec_1_1_train, sec_2_1_train, sec_3_1_train, sec_4_1_train, sec_5_1_train]
quat_train = pd.concat(quat_train_list, ignore_index=True)
print(quat_train.shape)

quat_val_list = [sec_1_1_val, sec_2_1_val, sec_3_1_val, sec_4_1_val]
quat_val = pd.concat(quat_val_list, ignore_index=True)
print(quat_val.shape)

f1  = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/PAE_new_sub2_train.csv"
pae_train.reset_index(drop=True, inplace=True)
pae_train.to_csv(f1, index=False)

f2  = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/PAE_new_sub2_val.csv"
pae_val.reset_index(drop=True, inplace=True)
pae_val.to_csv(f2, index=False)

f3  = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/Quat_new_sub2_train.csv"
quat_train.reset_index(drop=True, inplace=True)
quat_train.to_csv(f3, index=False)

f4  = "/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/Quat_new_sub2_val.csv"
quat_val.reset_index(drop=True, inplace=True)
quat_val.to_csv(f4, index=False)
# Out:
# (88000, 21)
# (19000, 21)
# (88000, 56)
# (19000, 56)

# %%
#################### FUnction to plot all the quaternion data ################

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.spatial.transform import Rotation as R

def normalize_np_quat(q):
    # Assume preds is your (50000, 7, 4) array of quaternions
    norm = np.linalg.norm(q, axis=-1, keepdims=True)  # shape: (50000, 7, 1)

    # Avoid divide-by-zero
    norm[norm == 0] = 1.0

    # Normalize
    q_norm = q / norm
    
    return q_norm   

def joint_angle_calculator(np_array):
    
    euler_angles = np.zeros((np_array.shape[0] , np_array.shape[1] // 4, 3))
    
    for i in range(np_array.shape[0]):
        for j in range(0, np_array.shape[1], 4):
            
            q = np_array[i, j:j+4]
            r = R.from_quat(q)
            euler = r.as_euler('xyz', degrees=True)
            euler_angles[i, j//4, :] = euler
            
    return euler_angles
            
df = pd.read_csv("/home/cshah/workspaces/deepPhase based work/Data/Full Training - Gyro + Joint Angles/Quat_Sub2_train.csv")

ss_df = df.iloc[:, 0:28]
cap_df = df.iloc[:, 28:56]


ss_angles = joint_angle_calculator( normalize_np_quat(ss_df.to_numpy()) )
cap_angles = joint_angle_calculator( normalize_np_quat(cap_df.to_numpy()) )




fig, axes = plt.subplots(cap_angles.shape[2], 7, figsize=(20,12), sharex=True)

joints = ss_df.columns

for i in range(cap_angles.shape[1]):
        
        # for j in range(len(pred_euler_angles)):
        #     sum = pred_euler_angles[j,i,0] ** 2 + pred_euler_angles[j,i,1] ** 2 + pred_euler_angles[j,i,2] ** 2 + pred_euler_angles[j,i,3] ** 2
        #     sum2 = ground_truth_euler_angles[j,i,0] ** 2 + ground_truth_euler_angles[j,i,1] ** 2 + ground_truth_euler_angles[j,i,2] ** 2 + ground_truth_euler_angles[j,i,3] ** 2
            
            # print("Sum 1: ", sum)
            # print("Sum 2: ", sum2)
            
        # Combine to compute display-centered y-axis limits
        combined = np.concatenate([cap_angles, ss_angles], axis=0)  # shape (2N, 3)

        
        axes[0,i].plot( cap_angles[:,i,0], linewidth=1, color="red")
        axes[0,i].plot( ss_angles[:,i,0], linewidth=0.75, color="black")
        axes[0,i].set_title(joints[i] + "_X ")
    
        
        axes[1,i].plot( cap_angles[:,i,1], linewidth=1, color="green")
        axes[1,i].plot( ss_angles[:,i,1], linewidth=0.75, color="black")
        axes[1,i].set_title(joints[i] + "_Y ")
        
        axes[2,i].plot( cap_angles[:,i,2], linewidth=1, color="blue")
        axes[2,i].plot( ss_angles[:,i,2], linewidth=0.75, color="black")
        axes[2,i].set_title(joints[i] + "_Z ")
        
        # if pred_euler_angles.shape[2] >= 4:
        #     for k in range(3, pred_euler_angles.shape[2]):
        #         axes[k,i].plot( pred_euler_angles[:,i,k], linewidth=1, color="blue")
        #         axes[k,i].plot( ground_truth_euler_angles[:,i,k], linewidth=0.75, color="black")
                
                
        #         axes[k,i].set_title(joints[i] + "_W ")
        
        
        # axes[0,i].set_ylim(-1.5,1.5)
        # axes[1,i].set_ylim(-1.5,1.5)
        # axes[2,i].set_ylim(-1.5,1.5)

plt.tight_layout()
    # plt.savefig(plot_save_name, dpi=300, bbox_inches='tight')
    # plt.close()
plt.show()
