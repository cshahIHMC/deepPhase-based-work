# %%
import pandas as pd 


csv_write = "/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/GATECH_config/07_09_combined_train.csv"
csv_write_validate = "/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/GATECH_config/07_09_combined_validate.csv"

# CSV's to read from
csv_files =  [
# "/home/cshah/workspaces/deepPhase based work/Data/07_02_FJC.csv",
# "/home/cshah/workspaces/deepPhase based work/Data/07_02_random_motions.csv",
# "/home/cshah/workspaces/deepPhase based work/Data/07_02_squats_quaternion_data.csv",
# "/home/cshah/workspaces/deepPhase based work/Data/07_02_walking_quaternion_data.csv",

# "/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_FJC.csv",
# "/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_random.csv",
# "/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_squats.csv",
# "/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_TW.csv",
# "/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_WA.csv"

"/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/GATECH_config/07_09_SQ.csv",
"/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/GATECH_config/07_09_TW_08.csv",
"/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/GATECH_config/07_09_TW_12.csv"

]

# Read and concatenate all CSVs
# FJC_df = pd.read_csv(csv_files[0])
# random_df = pd.read_csv(csv_files[1])
squats_df = pd.read_csv(csv_files[0])
treadmill_walking_df = pd.read_csv(csv_files[1])
treadmill_walking_df_2 = pd.read_csv(csv_files[2])
# walking_df = pd.read_csv(csv_files[4])

# print(len(FJC_df))
# print(len(random_df))
print(len(squats_df))
print(len(treadmill_walking_df))
print(len(treadmill_walking_df_2))

# random_df_train = random_df.iloc[4000:]
# random_df_validate = random_df.iloc[0:4000]

# squats_df_train = squats_df.iloc[5000:]
# squats_df_validate = squats_df.iloc[0:5000]

treadmill_walking_df_train = treadmill_walking_df.iloc[0:11000]
treadmill_walking_df_validate = treadmill_walking_df.iloc[11000:]

treadmill_walking_df_2_train = treadmill_walking_df.iloc[0:7500]
treadmill_walking_df_2_validate = treadmill_walking_df.iloc[7500:]

# walking_df_train = walking_df.iloc[7000:]
# walking_df_validate = walking_df.iloc[0:7000]

# df_list = [squats_df_train, treadmill_walking_df_train, treadmill_walking_df_train]
df_list = [squats_df, treadmill_walking_df_train, treadmill_walking_df_2_train]
combined_df = pd.concat(df_list, ignore_index=True)

# df_list_validate = [random_df_validate, squats_df_validate, treadmill_walking_df_validate, walking_df_validate]
df_list_validate = [treadmill_walking_df_train, treadmill_walking_df_2_train]
combined_df_validate = pd.concat(df_list_validate, ignore_index=True)
# Out:
# 5700
# 14000
# 10000

# %%
# Optional: sort or reset index
combined_df.reset_index(drop=True, inplace=True)
combined_df.to_csv(csv_write, index=False)

combined_df_validate.reset_index(drop=True, inplace=True)
combined_df_validate.to_csv(csv_write_validate, index=False)

# # Write all the validation files
# random_df_validate.reset_index(drop=True, inplace=True)
# random_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_random_validate.csv", index=False)

# squats_df_validate.reset_index(drop=True, inplace=True)
# squats_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_squats_validate.csv", index=False)

# treadmill_walking_df_validate.reset_index(drop=True, inplace=True)
# treadmill_walking_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_TW_validate.csv", index=False)

# walking_df_validate.reset_index(drop=True, inplace=True)
# walking_df_validate.to_csv("/home/cshah/workspaces/deepPhase based work/Data/07_09_Nicole/07_09_Nicole_WA_validate.csv", index=False)
